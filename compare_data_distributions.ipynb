# %%
import pandas as pd
import random
import numpy as np
import time

# %%
#link: https://pdf.sciencedirectassets.com/271498/1-s2.0-S0167715200X00508/1-s2.0-S0167715297000205/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEMz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJGMEQCIFCaEtfbJJJFG3DOPDvjkyUgyYpx1daupfxT3nVCYsuTAiBqNnrzLAL%2FKLfPE2eEOa%2FGnlbT3bx9bq7lZ2Emw7s4SSqDBAil%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAQaDDA1OTAwMzU0Njg2NSIM%2Bk%2FtppwsDcT9djvlKtcD4Zcvb4nFdWvrxyD6ShyMJwKlnKDp%2BJ%2Fz%2BpPJI%2BQfRI8VmkAHP8NyWieLnCRuWn%2FyP2ACIwfFEtsLw3kwWQg0RaUKj92dSx43%2Fot2Iq7CR7UFc002LNCwMXVqoWYBcy8Sfh6GOKUdZ8IBNqZuLhO2ElK7tpCuFE%2Bz8WMdULsKdK1nq6AtLct9pt5rfBsEDHRiXJrhWVD5VCJuSyLL7YV9%2Fxo03%2B2uixAdPd4jdZdZ4WkFC5glnES79xXX8jZGMqjxE8THr%2FVnQMEQ4%2BNh8bw2%2BRNTOGmnhWp13yittuDr1XUBwLScEnTKuX6HjfMUYaXNmW8By6a2s0Rhf2KQooRC3PaRZbucdistLwdXBKGTnkHdRoG5IcyYWAO4oymeUlnOMoiIUIvSaE4ozJDJMoKiaI2sHl04TgpcHnK4GVCglga2mXilYeY9FIW%2BT%2FiejVauoOQSW%2BuG7I6JtWSozWCMTEkLRW%2F7nymn0XvCOhY9%2FCR5dY7w%2FXGXVO2DPQiOixjgYN%2BWgVigwND0K5Z2XNpPGu91I6H%2Bp1%2Fg4uK1ALjpepd%2FTHtwApdzQZKWjXtft0SX2Vs45JV2B6Do7MhhQV6j2RzWtGqYgP2%2FilQW5ZkH%2Fr4FJQJwYTzoMMyKvY0GOqYBmEqRx%2BNPsVjfkqJTc0Pj2tqBt9lLtPxmAt8gqwfpS5%2BCROPUCPosoyAGSbEMZqQlQhlkIdU0FcZL0I7iaGRitI6K%2Ba80ouNr%2B9xFCAqju3lRl%2Bhib3JX5iFYPJnV9sZUUbRuHGX9Vsh6FBGqle8%2BlQmGHxagLyujIXFbNG0YZH0lot331XH%2BplBk%2BmkX1FTGGr2yLJuu5bHU4iUUtbrlmD5BrnY5Ow%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211207T120758Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYYCL5434P%2F20211207%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=55e49b003558e71e31ae8890fe4f8764cd4c86725bd5088f37a2d6c98b63c024&hash=6f6f0a93012850de6c28cf4a22846cc6e75f24e36188e9cbafe6c42b6f91daf4&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0167715297000205&tid=spdf-151feed1-2c74-4752-8e97-aeb2e643ffa7&sid=d4d443bd8ab3f842587a9f1786c5b6924c17gxrqb&type=client

#kolmogorov test shows if 2 data have the same distribution. However, it exists only for 1-variable data. The above link provides a way to do it with more than 2 variables, but it is really long.
#RosenBlatt showed how to reduce the dimensionnality of a distribution to 1, and it becomes an uniform law
#in UCI-HAR we have 561 variables, so it doesn't seem feasible

# %%
#link: https://reader.elsevier.com/reader/sd/pii/S0047259X03000794?token=46D4AB26C11D7C5BA3C0309E699CB2174E315A4252F4414498B5119CDEDFEF5F2367D9250451103FB96B28CE9C3C8BE1&originRegion=eu-west-1&originCreation=20211207122542


def euc_dist(a,b): #euclidian distance between 2 variables with n dimensions
    return np.linalg.norm(a-b)


def compute_stat_Baringhaus(first_data,second_data):
    try:
        first_data=first_data.reshape([first_data.shape[1], first_data.shape[0]])
        second_data=second_data.reshape([second_data.shape[1], second_data.shape[0]])
        len_seq_first_data=first_data.shape[1]
        len_seq_sec_data=second_data.shape[1]
    except IndexError:
        len_seq_first_data=len(first_data)
        len_seq_sec_data=len(second_data)
        vector=True
    nb_variables_first_data=first_data.shape[0]
    nb_variables_second_data=second_data.shape[0]


    mult_lens=len_seq_sec_data*len_seq_first_data
    sum_lens=len_seq_sec_data+len_seq_first_data
    sum_all_euc_dist=0
    for i in (range(nb_variables_first_data)):
        for j in range((nb_variables_second_data)):

            sum_all_euc_dist+=(euc_dist(first_data[i],second_data[j]))

    sum_euc_dist_intra_first_data=0
    for k in range(nb_variables_first_data):
        for l in range(nb_variables_first_data):
            sum_euc_dist_intra_first_data+=euc_dist(first_data[k],first_data[l])
    sum_euc_dist_intra_second_data=0
    for m in range(nb_variables_second_data):
        for n in range(nb_variables_second_data):
            sum_euc_dist_intra_second_data+=euc_dist(second_data[m],second_data[n])


    return ((mult_lens/sum_lens) * (
        ((1/mult_lens)*sum_all_euc_dist)-
        ((1/(2*len_seq_first_data*len_seq_first_data)) * sum_euc_dist_intra_first_data)-
        ((1/(2*len_seq_sec_data*len_seq_sec_data)) * sum_euc_dist_intra_second_data)
    ))

# %%
FILE='file_to_x_test_UCI-HAR.txt' #to replace in the below line
df=pd.read_csv(FILE, delim_whitespace=True, header=None)

# %%
df.head() #560 variables
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1  0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2  0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3  0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4  0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974  0.006462
# 1 -0.968401 -0.945823 -0.894088  ... -0.401189 -0.121845 -0.594944 -0.083495
# 2 -0.970735 -0.963483 -0.939260  ...  0.062891 -0.190422 -0.640736 -0.034956
# 3 -0.974471 -0.968897 -0.938610  ...  0.116695 -0.344418 -0.736124 -0.017067
# 4 -0.965953 -0.977346 -0.938610  ... -0.121711 -0.534685 -0.846595 -0.002223
#
#         555       556       557       558       559       560
# ...

# %%
#we use our tests on 100 successive samples in UCI-HAR
print(df.shape)

first_sample=df.iloc[100:200]
second_sample=df.iloc[200:300]

first_sample=first_sample.to_numpy()
second_sample=second_sample.to_numpy()

#faut reshape pour inverser
#first_sample=first_sample.reshape([first_sample.shape[1], first_sample.shape[0]])
#second_sample=second_sample.reshape([second_sample.shape[1], second_sample.shape[0]])
print(first_sample.shape)
print(second_sample.shape)
# Out:
# (2947, 561)
# (100, 561)
# (100, 561)

# %%
def H(p, q):
  # distance between p an d
  # p and q are np array probability distributions
    n = len(p) #doit correspondre à la longueur de la séquence
    #print(n)
    sum = 0.0
    for i in range(n):
        #sum += (np.sqrt(p[i]) - np.sqrt(q[i]))**2
        sum += (euc_dist(p[i],q[i]))
    result = (1.0 / np.sqrt(2.0)) * np.sqrt(sum)
    return result

tic = time.time()
print(H(first_sample,second_sample))
tac= time.time()
print(tac-tic)
# Out:
# 24.39842919979808
# 0.0

# %%
tic = time.time()
print(compute_stat_Baringhaus(first_sample,second_sample))
tac= time.time()
print(tac-tic)
# Out:
# 47.28787964968362
# 4.461581468582153

# %%
#on simule 2 variables aléatoires normales et on fait les tests avec
mu, sigma = 0, 0.1 # mean and standard deviation
s1 = np.random.normal(mu, sigma, 1000)
s2 = np.random.normal(mu, sigma, 1000)
print(H(s1,s2))
print(compute_stat_Baringhaus(s1,s2)) #p-value < 5%, as we can think
# Out:
# 7.431771486483939
# 0.018802205279656176
